# %%
import numpy as np
import pandas as pd
from pydataset import data
from pandas_profiling import ProfileReport

# %%
df_iris = data('iris')
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
df_iris.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0rc1&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-11 21:58:53.058094&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_excel = pd.read_excel('Table1_Customer_Details.xlsx')
df_excel
# Out:
#      customer_id churn  gender  is_senior_citizen partner dependents  \
# 0     9995-HOTOH    No    Male                  0     Yes        Yes
# 1     9993-LHIEB    No    Male                  0     Yes        Yes
# 2     9992-UJOEL    No    Male                  0      No         No
# 3     9992-RRAMN   Yes    Male                  0     Yes         No
# 4     9987-LUTYD    No  Female                  0      No         No
# ...          ...   ...     ...                ...     ...        ...
# 7038  0013-EXCHZ    No    Male                  0      No         No
# 7039  0011-IGKFF    No  Female                  0     Yes        Yes
# 7040  0004-TLHLJ    No  Female                  1      No         No
# 7041  0003-MKNFE    No    Male                  0     Yes         No
# 7042  0002-ORFBO    No  Female                  1     Yes         No
#
#       phone_service  internet_service  contract_type  \
# 0                 0                 1              2
# ...

# %%
df_excel.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0rc1&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-11 21:59:11.627810&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_excel_sample = df_excel.iloc[:100]
df_excel_sample
# Out:
#    customer_id churn  gender  is_senior_citizen partner dependents  \
# 0   9995-HOTOH    No    Male                  0     Yes        Yes
# 1   9993-LHIEB    No    Male                  0     Yes        Yes
# 2   9992-UJOEL    No    Male                  0      No         No
# 3   9992-RRAMN   Yes    Male                  0     Yes         No
# 4   9987-LUTYD    No  Female                  0      No         No
# 5   9986-BONCE   Yes  Female                  0      No         No
# 6   9985-MWVIX   Yes  Female                  0      No         No
# 7   9979-RGMZT    No  Female                  0      No         No
# 8   9978-HYCIN    No    Male                  1     Yes        Yes
# 9   9975-SKRNR    No    Male                  0      No         No
# 10  9975-GPKZU    No    Male                  0     Yes        Yes
# 11  9974-JFBHQ    No    Male                  0      No        Yes
# 12  9972-VAFJJ    No  Female                  1     Yes         No
# ...

# %%
df_excel.shape
# Out:
# (7043, 12)

# %%
df_excel.columns[:5]
# Out:
# Index(['customer_id', 'churn', 'gender', 'is_senior_citizen', 'partner'], dtype='object')

# %%
df_excel.dtypes[df_excel.dtypes == object]
# Out:
# customer_id     object
# churn           object
# gender          object
# partner         object
# dependents      object
# payment_type    object
# dtype: object

# %%
(df_excel[['monthly_charges', 'total_charges']].max()) - (df_excel[['monthly_charges', 'total_charges']].min())
# Out:
# monthly_charges     100.5
# total_charges      8666.0
# dtype: float64

# %%
url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'
export_url = url.replace('/edit#gid=', '/export?format=csv&gid=')
df_google= pd.read_csv(export_url)

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.shape
# Out:
# (891, 12)

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_google.Sex.value_counts(), df_google.SibSp.value_counts(), df_google.Pclass.value_counts(), df_google.Survived.value_counts()
# Out:
# (male      577
#  female    314
#  Name: Sex, dtype: int64,
#  0    608
#  1    209
#  2     28
#  4     18
#  3     16
#  8      7
#  5      5
#  Name: SibSp, dtype: int64,
#  3    491
#  1    216
#  2    184
#  Name: Pclass, dtype: int64,
#  0    549
#  1    342
#  Name: Survived, dtype: int64)
